# %% [markdown]
# # Introduction (Ch 1)

# %% [markdown]
# In this course you will be using the Python computing language to do all your computational work.
#
# This may seem as a surprise, since the videos use Minitab and Excel.
#
# But given the change in the world around us, we found it most beneficial if you gained Python computing skills as part of this course. While you will be using many standard functions and methods, you should gain a better understanding of the Quality Control principles.
#
# This is a Jupyter notebook. It consists of two types of cells: Markdown and Code.
#
# This cell is a Markdown for text. Code cells contain Python code, which you can execute on the spot, by highlighting a cell, and pressing Run above.
#
# When you solve practice quizzes and tests, you will producing you own Jupyter notebooks with the answers, also including Markdown cells for your answers and explanations, and Code to perform the computations.
#
# There will be a Jupyter notebook for each of the 12 chapters. While this chapter requires no computations we will use it as an introduction to Python, as it relates to this course.
#
# To start Run the code below, by clicking on Run (3rd row from the top)

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# Python carries out its computations using functions and methods. Functions you are familiar with as they are very close to calculus functions. print is a function. Methods are a bit different in that they operate on an object.
#
# Rather than give you abstract examples, you will learn these concepts by using functions and methods to carry out the required computations.
#
# Let us use Python to import data in python_test_data.csv to a dataframe object - the equivalent of an excel sheet within Python.
#
# You will need to import the pandas package, which contains the required function read_csv.
#
# After bringing in a csv data file into the same directory as this file you can execute the file below.

# %%
import pandas as pd
df = pd.read_csv('python_test_data.csv')

# %% [markdown]
# If you received no errors, all seems fine. But now we need a method to produce some output. We use the head method.

# %%
df.head()
# Out:
#    width  height
# 0   2.91    0.03
# 1   6.07   12.17
# 2   1.22    0.78
# 3   6.37    8.26
# 4   1.75    5.84

# %% [markdown]
# Note how the method works as opposed to a function. You might have expected to use head(df) which is a function. A method, first notes the object, in this cased df, and then operates on that object, without the need of any further input, i.e. df.head().

# %% [markdown]
# # Methods introduced in this chapter
#
# This chapter introduced the functions print and pandas.read_csv, and the method pandas.head.
#
# For the next chapters we will list the new functions and methods introduced at the beginning of the notebook, followed by an example of the use of each function and method.
#
# You should then be prepared to do practice quizzes using Python.
#
# # Help function
#
# This is a backup function that while  it looks very complicated can be useful. See below on help for the function and methods we covered.

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
#     Read a comma-separated values (csv) file into DataFrame.
#
# ...

# %% [markdown]
# To get help on a method, you need to operate the methid on an appropriate object in your program, in our case df.

# %%
help(df.head)
# Out:
# Help on method head in module pandas.core.generic:
#
# head(n=5) method of pandas.core.frame.DataFrame instance
#     Return the first `n` rows.
#
#     This function returns the first `n` rows for the object based
#     on position. It is useful for quickly testing if your object
#     has the right type of data in it.
#
#     Parameters
#     ----------
#     n : int, default 5
#         Number of rows to select.
#
#     Returns
#     -------
#     obj_head : same type as caller
#         The first `n` rows of the caller object.
#
#     See Also
#     --------
#     DataFrame.tail: Returns the last `n` rows.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({'animal':['alligator', 'bee', 'falcon', 'lion',
#     ...                    'monkey', 'parrot', 'shark', 'whale', 'zebra']})
#     >>> df
#           animal
#     0  alligator
#     1        bee
#     2     falcon
#     3       lion
#     4     monkey
#     5     parrot
#     6      shark
#     7      whale
# ...

# %% [markdown]
# ## And one more useful bit...Keyboard Shortcuts under the Jupyter help (second row from the top of this page - File at the left - Help at the right end.
#
# ### For example to run a cell, instead of clicking on Run, enter shift-enter. Try it!
